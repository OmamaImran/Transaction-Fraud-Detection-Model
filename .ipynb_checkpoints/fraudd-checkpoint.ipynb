# %%
import pandas as pd

# %%
df= pd.read_excel("C:\\Users\\www\\Downloads\\Fraud.xlsx","Fraud")

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
dfd= df.drop(["nameOrig","nameDest","step","isFlaggedFraud"],axis= "columns")

# %%
dfd.head()
# Out:
#        type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2  TRANSFER    181.00          181.0            0.00             0.0
# 3  CASH_OUT    181.00          181.0            0.00         21182.0
# 4   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud
# 0             0.0        0
# 1             0.0        0
# 2             0.0        1
# 3             0.0        1
# 4             0.0        0

# %%
inputs=dfd.drop("isFraud",axis="columns")

# %%
ans= dfd.isFraud

# %%
from sklearn.model_selection import train_test_split

# %%
payment= dfd[dfd.type=="PAYMENT"]
transfer=dfd[dfd.type=="TRANSFER"]
cash_in=dfd[dfd.type=="CASH_IN"]
cashout=dfd[dfd.type=="CASH_OUT"]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
inputs_le= LabelEncoder()

# %%
inputs["TYPE"]= inputs_le.fit_transform(inputs["type"])

# %%
inputs= inputs.drop(["type"],axis="columns")

# %%
inputs
# Out:
#             amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0          9839.64      170136.00       160296.36            0.00
# 1          1864.28       21249.00        19384.72            0.00
# 2           181.00         181.00            0.00            0.00
# 3           181.00         181.00            0.00        21182.00
# 4         11668.14       41554.00        29885.86            0.00
# ...            ...            ...             ...             ...
# 1048570  132557.35      479803.00       347245.65       484329.37
# 1048571    9917.36       90545.00        80627.64            0.00
# 1048572   14140.05       20545.00         6404.95            0.00
# 1048573   10020.05       90605.00        80584.95            0.00
# 1048574   11450.03       80584.95        69134.92            0.00
#
#          newbalanceDest  TYPE
# 0                  0.00     3
# 1                  0.00     3
# 2                  0.00     4
# 3                  0.00     1
# ...

# %%
X_train, X_test, Y_train, _Ytest= train_test_split(inputs, ans, test_size=0.3)

# %%
from sklearn import tree

# %%
model= tree.DecisionTreeClassifier()

# %%
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test, _Ytest)
# Out:
# 0.9995644890057316

# %%
model.predict([[500,580,80,0,0,4]])
# Out:
# array([1], dtype=int64)

# %%
import pickle

# %%
separate= df

# %%
separate.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
separate["Origg"]= separate["nameOrig"].str[0]
separate["Dest"]= separate["nameDest"].str[0]

# %%
separate
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT    9839.64  C1231006815      170136.00
# 1           1   PAYMENT    1864.28  C1666544295       21249.00
# 2           1  TRANSFER     181.00  C1305486145         181.00
# 3           1  CASH_OUT     181.00   C840083671         181.00
# 4           1   PAYMENT   11668.14  C2048537720       41554.00
# ...       ...       ...        ...          ...            ...
# 1048570    95  CASH_OUT  132557.35  C1179511630      479803.00
# 1048571    95   PAYMENT    9917.36  C1956161225       90545.00
# 1048572    95   PAYMENT   14140.05  C2037964975       20545.00
# 1048573    95   PAYMENT   10020.05  C1633237354       90605.00
# 1048574    95   PAYMENT   11450.03  C1264356443       80584.95
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %% [raw]
# Orig_le = LabelEncoder()

# %%
Orig_le = LabelEncoder()
Dest_le= LabelEncoder()

# %%
separate["Orig_le"]= Orig_le.fit_transform(separate["Origg"])
separate["Dest_le"]= Orig_le.fit_transform(separate["Dest"])
